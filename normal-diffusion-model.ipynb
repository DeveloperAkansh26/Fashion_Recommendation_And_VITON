# %%
import torch
from PIL import Image
import numpy as np
from diffusers import AutoencoderKL, UNet2DConditionModel, DPMSolverMultistepScheduler
from transformers import CLIPTextModel, CLIPTokenizer
import os


device = "cuda" if torch.cuda.is_available() else "cpu"
model_id = "stabilityai/stable-diffusion-2-base"
torch_dtype = torch.float16


vae = AutoencoderKL.from_pretrained(model_id, subfolder="vae", torch_dtype=torch.float16).to(device)
unet = UNet2DConditionModel.from_pretrained(model_id, subfolder="unet", torch_dtype=torch.float16).to(device)
tokenizer = CLIPTokenizer.from_pretrained(model_id, subfolder="tokenizer")
text_encoder = CLIPTextModel.from_pretrained(model_id, subfolder="text_encoder", torch_dtype=torch.float16).to(device)
scheduler = DPMSolverMultistepScheduler.from_pretrained(model_id, subfolder="scheduler")
print("All components loaded successfully.")


prompt = "Generate an image of top only with following description: Floral drees suitable for party"
negative_prompt = "picture containing pants, jeans trounsers, any type of background beside white"
guidance_scale = 8.0
num_inference_steps = 50
seed = 42
generator = torch.Generator(device=device).manual_seed(seed)


text_input_ids = tokenizer(prompt, padding="max_length", truncation=True, return_tensors="pt").input_ids.to(device)
conditional_embeddings = text_encoder(text_input_ids)[0]
print(f"Conditional text embeddings shape: {conditional_embeddings.shape}")

uncond_input_ids = tokenizer(negative_prompt, padding="max_length", truncation=True, return_tensors="pt").input_ids.to(device)
unconditional_embeddings = text_encoder(uncond_input_ids)[0]
print(f"Unconditional text embeddings shape: {unconditional_embeddings.shape}")

text_embeddings = torch.cat([unconditional_embeddings, conditional_embeddings])
print(f"Combined text embeddings shape (for CFG): {text_embeddings.shape}")


latents = torch.randn(1, vae.config.latent_channels, unet.config.sample_size, unet.config.sample_size, generator=generator, device=device, dtype=torch.float16)
print(f"Initial latents shape: {latents.shape}")
print(f"Initial latents min: {latents.min().item():.4f}, max: {latents.max().item():.4f}, mean: {latents.mean().item():.4f}, std: {latents.std().item():.4f}")


scheduler.set_timesteps(num_inference_steps, device=device)
print(f"Scheduler timesteps set: {scheduler.timesteps.shape[0]} steps.")
print(f"Scheduler timesteps: {scheduler.timesteps.tolist()}")

latents = latents * scheduler.init_noise_sigma
print(f"Latents after initial setup (with init_noise_sigma scaling): {latents.min().item():.4f}, max: {latents.max().item():.4f}, mean: {latents.mean().item():.4f}, std: {latents.std().item():.4f}")

print("Starting denoising process...")
with torch.no_grad():
    for i, t in enumerate(scheduler.timesteps):

        latent_model_input = torch.cat([latents] * 2)
        latent_model_input = scheduler.scale_model_input(latent_model_input, t)

        noise_pred = unet(latent_model_input, t, encoder_hidden_states=text_embeddings).sample
        print(f"  Step {i+1} (Timestep {t.item()}): Noise Pred Min: {noise_pred.min().item():.4f}, Max: {noise_pred.max().item():.4f}, Mean: {noise_pred.mean().item():.4f}")

        noise_pred_uncond, noise_pred_text = noise_pred.chunk(2)
        noise_pred = noise_pred_uncond + guidance_scale * (noise_pred_text - noise_pred_uncond)

        latents = scheduler.step(noise_pred, t, latents).prev_sample
        print(f"  Step {i+1} (Timestep {t.item()}): Latents Min: {latents.min().item():.4f}, Max: {latents.max().item():.4f}, Mean: {latents.mean().item():.4f}, Std: {latents.std().item():.4f}")

print("Denoising process completed.")


latents = 1 / vae.config.scaling_factor * latents
print(f"Latents (before VAE decode) min: {latents.min().item():.4f}, max: {latents.max().item():.4f}, mean: {latents.mean().item():.4f}, std: {latents.std().item():.4f}")

print("Decoding latents to image...")
image = vae.decode(latents).sample
print("Image decoded.")
print(f"Decoded image min: {image.min().item():.4f}, max: {image.max().item():.4f}, mean: {image.mean().item():.4f}")


image = torch.clamp(image, -1, 1)
image = (image / 2 + 0.5)
image = torch.clamp(image, 0, 1)
img = image.squeeze(0)
img = (img * 255).byte()
img = img.permute(1, 2, 0).detach().cpu().numpy()
img = Image.fromarray(img)
print("Image prepared for display.")
# Out:
# All components loaded successfully.
# Conditional text embeddings shape: torch.Size([1, 77, 1024])
# Unconditional text embeddings shape: torch.Size([1, 77, 1024])
# Combined text embeddings shape (for CFG): torch.Size([2, 77, 1024])
# Initial latents shape: torch.Size([1, 4, 64, 64])
# Initial latents min: -3.9277, max: 3.9316, mean: 0.0031, std: 0.9971
# Scheduler timesteps set: 50 steps.
# Scheduler timesteps: [999, 979, 959, 939, 919, 899, 879, 859, 839, 819, 799, 779, 759, 739, 719, 699, 679, 659, 639, 619, 599, 579, 559, 539, 519, 500, 480, 460, 440, 420, 400, 380, 360, 340, 320, 300, 280, 260, 240, 220, 200, 180, 160, 140, 120, 100, 80, 60, 40, 20]
# Latents after initial setup (with init_noise_sigma scaling): -3.9277, max: 3.9316, mean: 0.0031, std: 0.9971
# Starting denoising process...
#   Step 1 (Timestep 999): Noise Pred Min: -3.9238, Max: 3.9336, Mean: 0.0030
#   Step 1 (Timestep 999): Latents Min: -3.9355, Max: 3.9277, Mean: 0.0052, Std: 0.9966
#   Step 2 (Timestep 979): Noise Pred Min: -3.9297, Max: 3.9316, Mean: 0.0034
#   Step 2 (Timestep 979): Latents Min: -3.9414, Max: 3.9199, Mean: 0.0065, Std: 0.9966
#   Step 3 (Timestep 959): Noise Pred Min: -3.9316, Max: 3.9297, Mean: 0.0033
#   Step 3 (Timestep 959): Latents Min: -3.9473, Max: 3.9082, Mean: 0.0082, Std: 0.9966
#   Step 4 (Timestep 939): Noise Pred Min: -3.9277, Max: 3.9238, Mean: 0.0029
#   Step 4 (Timestep 939): Latents Min: -3.9512, Max: 3.9023, Mean: 0.0106, Std: 0.9971
#   Step 5 (Timestep 919): Noise Pred Min: -3.9238, Max: 3.9277, Mean: -0.0007
#   Step 5 (Timestep 919): Latents Min: -3.9551, Max: 3.9062, Mean: 0.0082, Std: 0.9966
#   Step 6 (Timestep 899): Noise Pred Min: -3.9258, Max: 3.9336, Mean: -0.0012
#   Step 6 (Timestep 899): Latents Min: -3.9570, Max: 3.9102, Mean: 0.0086, Std: 0.9971
#   Step 7 (Timestep 879): Noise Pred Min: -3.9238, Max: 3.9316, Mean: -0.0027
#   Step 7 (Timestep 879): Latents Min: -3.9609, Max: 3.9082, Mean: 0.0081, Std: 0.9966
#   Step 8 (Timestep 859): Noise Pred Min: -3.9258, Max: 3.9336, Mean: -0.0034
#   Step 8 (Timestep 859): Latents Min: -3.9629, Max: 3.9102, Mean: 0.0077, Std: 0.9961
#   Step 9 (Timestep 839): Noise Pred Min: -3.9238, Max: 3.9316, Mean: -0.0027
#   Step 9 (Timestep 839): Latents Min: -3.9668, Max: 3.9082, Mean: 0.0080, Std: 0.9961
#   Step 10 (Timestep 819): Noise Pred Min: -3.9180, Max: 3.9219, Mean: -0.0026
#   Step 10 (Timestep 819): Latents Min: -3.9629, Max: 3.9043, Mean: 0.0083, Std: 0.9951
#   Step 11 (Timestep 799): Noise Pred Min: -3.9121, Max: 3.9141, Mean: -0.0019
#   Step 11 (Timestep 799): Latents Min: -3.9609, Max: 3.8965, Mean: 0.0086, Std: 0.9946
#   Step 12 (Timestep 779): Noise Pred Min: -3.9121, Max: 3.9121, Mean: -0.0012
#   Step 12 (Timestep 779): Latents Min: -3.9531, Max: 3.8848, Mean: 0.0090, Std: 0.9932
#   Step 13 (Timestep 759): Noise Pred Min: -3.9316, Max: 3.9355, Mean: -0.0006
#   Step 13 (Timestep 759): Latents Min: -3.9395, Max: 3.8711, Mean: 0.0100, Std: 0.9917
#   Step 14 (Timestep 739): Noise Pred Min: -3.9375, Max: 3.9492, Mean: -0.0005
#   Step 14 (Timestep 739): Latents Min: -3.9277, Max: 3.8652, Mean: 0.0110, Std: 0.9897
#   Step 15 (Timestep 719): Noise Pred Min: -3.9395, Max: 3.9434, Mean: -0.0005
#   Step 15 (Timestep 719): Latents Min: -3.9160, Max: 3.8633, Mean: 0.0119, Std: 0.9883
#   Step 16 (Timestep 699): Noise Pred Min: -3.9434, Max: 3.9160, Mean: -0.0005
#   Step 16 (Timestep 699): Latents Min: -3.9062, Max: 3.8691, Mean: 0.0131, Std: 0.9868
#   Step 17 (Timestep 679): Noise Pred Min: -3.9473, Max: 3.8594, Mean: -0.0005
#   Step 17 (Timestep 679): Latents Min: -3.8965, Max: 3.8848, Mean: 0.0143, Std: 0.9849
#   Step 18 (Timestep 659): Noise Pred Min: -3.9453, Max: 3.7500, Mean: -0.0007
#   Step 18 (Timestep 659): Latents Min: -4.0312, Max: 3.8730, Mean: 0.0154, Std: 0.9829
#   Step 19 (Timestep 639): Noise Pred Min: -3.9492, Max: 3.7051, Mean: -0.0008
#   Step 19 (Timestep 639): Latents Min: -4.1914, Max: 3.8711, Mean: 0.0166, Std: 0.9810
#   Step 20 (Timestep 619): Noise Pred Min: -3.9570, Max: 3.6406, Mean: -0.0009
#   Step 20 (Timestep 619): Latents Min: -4.3672, Max: 3.8672, Mean: 0.0177, Std: 0.9785
#   Step 21 (Timestep 599): Noise Pred Min: -3.9648, Max: 3.5840, Mean: -0.0010
#   Step 21 (Timestep 599): Latents Min: -4.5664, Max: 3.8594, Mean: 0.0188, Std: 0.9761
#   Step 22 (Timestep 579): Noise Pred Min: -3.9648, Max: 3.5352, Mean: -0.0010
#   Step 22 (Timestep 579): Latents Min: -4.7734, Max: 3.8496, Mean: 0.0199, Std: 0.9731
#   Step 23 (Timestep 559): Noise Pred Min: -3.9531, Max: 3.5371, Mean: -0.0010
#   Step 23 (Timestep 559): Latents Min: -4.9844, Max: 3.8340, Mean: 0.0210, Std: 0.9702
#   Step 24 (Timestep 539): Noise Pred Min: -3.9297, Max: 3.5449, Mean: -0.0010
#   Step 24 (Timestep 539): Latents Min: -5.1953, Max: 3.8105, Mean: 0.0220, Std: 0.9668
#   Step 25 (Timestep 519): Noise Pred Min: -3.9141, Max: 3.5488, Mean: -0.0010
#   Step 25 (Timestep 519): Latents Min: -5.3984, Max: 3.7930, Mean: 0.0231, Std: 0.9634
#   Step 26 (Timestep 500): Noise Pred Min: -3.9043, Max: 3.5488, Mean: -0.0010
#   Step 26 (Timestep 500): Latents Min: -5.6094, Max: 3.7754, Mean: 0.0241, Std: 0.9595
#   Step 27 (Timestep 480): Noise Pred Min: -3.8906, Max: 3.5410, Mean: -0.0009
#   Step 27 (Timestep 480): Latents Min: -5.8203, Max: 3.7539, Mean: 0.0251, Std: 0.9551
#   Step 28 (Timestep 460): Noise Pred Min: -3.8867, Max: 3.5332, Mean: -0.0009
#   Step 28 (Timestep 460): Latents Min: -6.0312, Max: 3.7500, Mean: 0.0261, Std: 0.9507
#   Step 29 (Timestep 440): Noise Pred Min: -3.8828, Max: 3.5234, Mean: -0.0010
#   Step 29 (Timestep 440): Latents Min: -6.2344, Max: 3.8828, Mean: 0.0271, Std: 0.9463
#   Step 30 (Timestep 420): Noise Pred Min: -3.8789, Max: 3.5117, Mean: -0.0010
#   Step 30 (Timestep 420): Latents Min: -6.4336, Max: 4.0156, Mean: 0.0281, Std: 0.9419
#   Step 31 (Timestep 400): Noise Pred Min: -3.8711, Max: 3.4980, Mean: -0.0011
#   Step 31 (Timestep 400): Latents Min: -6.6289, Max: 4.1484, Mean: 0.0291, Std: 0.9370
#   Step 32 (Timestep 380): Noise Pred Min: -3.8555, Max: 3.4824, Mean: -0.0011
#   Step 32 (Timestep 380): Latents Min: -6.8164, Max: 4.2812, Mean: 0.0300, Std: 0.9321
#   Step 33 (Timestep 360): Noise Pred Min: -3.8418, Max: 3.4648, Mean: -0.0011
#   Step 33 (Timestep 360): Latents Min: -7.0000, Max: 4.4102, Mean: 0.0309, Std: 0.9272
#   Step 34 (Timestep 340): Noise Pred Min: -3.8301, Max: 3.4453, Mean: -0.0011
#   Step 34 (Timestep 340): Latents Min: -7.1758, Max: 4.5352, Mean: 0.0318, Std: 0.9229
#   Step 35 (Timestep 320): Noise Pred Min: -3.8203, Max: 3.4180, Mean: -0.0011
#   Step 35 (Timestep 320): Latents Min: -7.3438, Max: 4.6602, Mean: 0.0326, Std: 0.9175
#   Step 36 (Timestep 300): Noise Pred Min: -3.8125, Max: 3.3730, Mean: -0.0012
#   Step 36 (Timestep 300): Latents Min: -7.5078, Max: 4.7812, Mean: 0.0334, Std: 0.9126
#   Step 37 (Timestep 280): Noise Pred Min: -3.7969, Max: 3.2930, Mean: -0.0012
#   Step 37 (Timestep 280): Latents Min: -7.6602, Max: 4.8945, Mean: 0.0342, Std: 0.9077
#   Step 38 (Timestep 260): Noise Pred Min: -3.7812, Max: 3.2227, Mean: -0.0012
#   Step 38 (Timestep 260): Latents Min: -7.8047, Max: 5.0039, Mean: 0.0350, Std: 0.9033
#   Step 39 (Timestep 240): Noise Pred Min: -3.7598, Max: 3.1738, Mean: -0.0012
#   Step 39 (Timestep 240): Latents Min: -7.9375, Max: 5.1055, Mean: 0.0358, Std: 0.8984
#   Step 40 (Timestep 220): Noise Pred Min: -3.7324, Max: 3.1406, Mean: -0.0013
#   Step 40 (Timestep 220): Latents Min: -8.0625, Max: 5.1992, Mean: 0.0365, Std: 0.8940
#   Step 41 (Timestep 200): Noise Pred Min: -3.6680, Max: 3.1094, Mean: -0.0013
#   Step 41 (Timestep 200): Latents Min: -8.1719, Max: 5.2852, Mean: 0.0372, Std: 0.8896
#   Step 42 (Timestep 180): Noise Pred Min: -3.6035, Max: 3.0762, Mean: -0.0013
#   Step 42 (Timestep 180): Latents Min: -8.2656, Max: 5.3672, Mean: 0.0379, Std: 0.8853
#   Step 43 (Timestep 160): Noise Pred Min: -3.5371, Max: 3.0332, Mean: -0.0013
#   Step 43 (Timestep 160): Latents Min: -8.3516, Max: 5.4375, Mean: 0.0385, Std: 0.8809
#   Step 44 (Timestep 140): Noise Pred Min: -3.4551, Max: 2.9824, Mean: -0.0012
#   Step 44 (Timestep 140): Latents Min: -8.4453, Max: 5.5039, Mean: 0.0391, Std: 0.8770
#   Step 45 (Timestep 120): Noise Pred Min: -3.3594, Max: 2.9512, Mean: -0.0012
#   Step 45 (Timestep 120): Latents Min: -8.5312, Max: 5.5625, Mean: 0.0396, Std: 0.8730
#   Step 46 (Timestep 100): Noise Pred Min: -3.2656, Max: 2.9160, Mean: -0.0011
#   Step 46 (Timestep 100): Latents Min: -8.6094, Max: 5.6133, Mean: 0.0402, Std: 0.8691
#   Step 47 (Timestep 80): Noise Pred Min: -3.1660, Max: 2.8555, Mean: -0.0009
#   Step 47 (Timestep 80): Latents Min: -8.6797, Max: 5.6602, Mean: 0.0406, Std: 0.8657
#   Step 48 (Timestep 60): Noise Pred Min: -3.0430, Max: 2.7363, Mean: -0.0008
#   Step 48 (Timestep 60): Latents Min: -8.7422, Max: 5.6992, Mean: 0.0411, Std: 0.8628
#   Step 49 (Timestep 40): Noise Pred Min: -2.8418, Max: 2.4980, Mean: -0.0006
#   Step 49 (Timestep 40): Latents Min: -8.8047, Max: 5.7305, Mean: 0.0415, Std: 0.8599
#   Step 50 (Timestep 20): Noise Pred Min: -2.4395, Max: 2.1250, Mean: -0.0003
#   Step 50 (Timestep 20): Latents Min: -8.8281, Max: 5.7305, Mean: 0.0419, Std: 0.8486
# Denoising process completed.
# Latents (before VAE decode) min: -48.4688, max: 31.4531, mean: 0.2300, std: 4.6602
# Decoding latents to image...
# Image decoded.
# Decoded image min: -1.1641, max: 1.1523, mean: -0.1349
# Image prepared for display.

# %%
img
