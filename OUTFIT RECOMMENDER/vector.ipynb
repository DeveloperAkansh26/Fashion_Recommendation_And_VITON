# %%
import os
import time
import json
from PIL import Image
import re
from google import genai
from dotenv import load_dotenv
from sentence_transformers import SentenceTransformer
import chromadb
from concurrent.futures import ThreadPoolExecutor, TimeoutError
from chromadb.api.types import EmbeddingFunction
import google.generativeai  as genai
from langchain.vectorstores import Chroma

# Load environment variables
load_dotenv()

# Configure Gemini API
genai.configure(api_key="AIzaSyDqCXvy2u5g8r6tLIU1Rsh9yCIBNFC9TPI")
client = genai.GenerativeModel("gemini-2.0-flash")

def gemini_api_request(prompt, image=None, timeout=25):
    def make_request():
        try:
            
            if image is not None:
                content = [image, prompt]  
            else:
                content = [prompt]  # just prompt

            content = [c for c in content if c is not None]

            response = client.generate_content(content)
            return response.text
        except Exception as e:
            print(f"API Error: {e}")
            return None

    with ThreadPoolExecutor(max_workers=1) as executor:
        future = executor.submit(make_request)
        try:
            return future.result(timeout=timeout)
        except TimeoutError:
            print("Request timed out.")
            return None


# Initialize ChromaDB
import chromadb

chromadb_client = chromadb.PersistentClient(path="./chroma_storage")

# Load embedding model
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2", device="cpu")

class MyEmbeddingFunction(EmbeddingFunction):
    def __init__(self, model):
        self.model = model

    def __call__(self, texts):
        return self.model.encode(texts).tolist()

    def embed_documents(self, texts):
        return self.model.encode(texts, show_progress_bar=False).tolist()

    def embed_query(self, text: str) -> list:
        return self.model.encode([text])[0].tolist()

embedding_fn = MyEmbeddingFunction(model)

collection = chromadb_client.get_or_create_collection(name="fashion_summaries2",
    embedding_function=embedding_fn)

vectorstore = Chroma(
    collection_name="fashion_summaries2",
    client=chromadb_client,
    embedding_function=embedding_fn,
)
done=1641
# Image folder path
image_folder = "clothes_tryon_dataset/train/cloth"
max_images = 2000 # Change as needed
image_files = sorted([
    f for f in os.listdir(image_folder)
    if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
])[:max_images]

# %%
prompt = """
You are an expert fashion analyst. Carefully examine the clothing item in the provided image.
Your task is to extract its key fashion attributes.
Pay close attention to details, especially variations in color and specific design elements.

Provide the extracted attributes as a JSON object. Ensure all string values are lowercase and replace any spaces with hyphens (e.g., 'long-sleeve', 'crew-neck'). If an attribute is not present or clearly identifiable, use 'n/a' as its value.

JSON Schema:
{
    "category": "string",
    "clothing_type": "string",
    "dominant_color": "string",
    "secondary_color": "string",
    "color_details": "string",
    "pattern": "string",
    "sleeve_type": "string",
    "neckline": "string",
    "fit": "string",
    "material_texture": "string",
    "closure_type": "string",
    "details": "string",
    "season": "string",
    "silhouette": "string",
    "hue": "string",
    "brightness": "string",
    "saturation": "string",
    "temperature": "string"
}

Example:
{
    "category": "top",
    "clothing_type": "shirt", "dominant_color": "blue",
    "secondary_color": "white",
    "color_details": "blue-with-white-collar",
    "pattern": "striped",
    "sleeve_type": "long-sleeve",
    "neckline": "collared",
    "fit": "regular",
    "material_texture": "cotton",
    "closure_type": "button-up",
    "details": "n/a",
    "season": "spring",
    "silhouette": "a",
    "hue": "cool",
     "brightness": "medium",
    "saturation": "high",
    "temperature": "warm"
}
"""

# %%
MAX_RETRIES = 5
RETRY_DELAY = 30  # seconds; Gemini recommends waiting ~30s after 429s

for idx, img_file in enumerate(image_files[done:], start=done):
    img_file = image_files[idx]
    img_path = os.path.join(image_folder, img_file)
    image = Image.open(img_path)

    # -------------------- ATTRIBUTE EXTRACTION --------------------
    for attempt in range(MAX_RETRIES):
        attributes_JSON = gemini_api_request(prompt, image)

        if attributes_JSON is None:
            print(f"[{img_file}] Attempt {attempt+1}: Gemini returned None. Retrying in {RETRY_DELAY}s...")
            time.sleep(RETRY_DELAY)
            continue

        match = re.search(r'```json\n(.*?)\n```', attributes_JSON, re.DOTALL)
        attributes_JSON_str = match.group(1) if match else attributes_JSON

        try:
            item_attributes = json.loads(attributes_JSON_str)
            if not isinstance(item_attributes, dict):
                raise ValueError("Parsed JSON is not a dictionary.")
            if not all(k in item_attributes for k in ["category", "clothing_type", "dominant_color"]):
                raise ValueError("Missing essential attributes.")
            break  # Success
        except (json.JSONDecodeError, ValueError) as e:
            print(f"[{img_file}] JSON Error: {e}")
            print(f"Output snippet: {attributes_JSON_str[:200]}...\nRetrying in {RETRY_DELAY}s...")
            time.sleep(RETRY_DELAY)
    else:
        print(f"[{img_file}] Failed to extract attributes after {MAX_RETRIES} attempts. Skipping.\n")
        continue

    # -------------------- SUMMARY GENERATION --------------------
    summary_prompt = f"""
You are a fashion assistant. Based on the following clothing attributes, write a short, natural-sounding summary describing the item. Avoid technical jargon. Use normal everyday language.

Attributes:
{json.dumps(item_attributes, indent=2)}

Summary:
"""

    for attempt in range(MAX_RETRIES):
        summary = gemini_api_request(summary_prompt, image)
        if summary:
            break
        print(f"[{img_file}] Summary gen failed. Attempt {attempt+1}. Retrying in {RETRY_DELAY}s...")
        time.sleep(RETRY_DELAY)
    else:
        print(f"[{img_file}] Summary gen failed after {MAX_RETRIES} attempts. Skipping.\n")
        continue

    # -------------------- STORE TO CHROMADB --------------------
    item_id = os.path.splitext(img_file)[0]
    metadata_to_store = {"image_file": img_file}
    metadata_to_store.update(item_attributes)

    collection.add(
        documents=[summary],
        metadatas=[metadata_to_store],
        ids=[item_id]
    )
    
    print(f"✅ Processed {img_file} ({idx+1}/{len(image_files)})\n")
# Out:
# ✅ Processed 02110_00.jpg (1642/2000)
#
# ✅ Processed 02111_00.jpg (1643/2000)
#
# ✅ Processed 02112_00.jpg (1644/2000)
#
# ✅ Processed 02113_00.jpg (1645/2000)
#
# ✅ Processed 02114_00.jpg (1646/2000)
#
# ✅ Processed 02117_00.jpg (1647/2000)
#
# ✅ Processed 02119_00.jpg (1648/2000)
#
# ✅ Processed 02120_00.jpg (1649/2000)
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# [02121_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# ✅ Processed 02121_00.jpg (1650/2000)
#
# ✅ Processed 02122_00.jpg (1651/2000)
#
# ✅ Processed 02123_00.jpg (1652/2000)
#
# ✅ Processed 02124_00.jpg (1653/2000)
#
# ✅ Processed 02125_00.jpg (1654/2000)
#
# ✅ Processed 02126_00.jpg (1655/2000)
#
# ✅ Processed 02127_00.jpg (1656/2000)
#
# ✅ Processed 02129_00.jpg (1657/2000)
#
# ✅ Processed 02130_00.jpg (1658/2000)
#
# ✅ Processed 02131_00.jpg (1659/2000)
#
# ✅ Processed 02132_00.jpg (1660/2000)
#
# ✅ Processed 02133_00.jpg (1661/2000)
#
# ✅ Processed 02135_00.jpg (1662/2000)
#
# ✅ Processed 02137_00.jpg (1663/2000)
#
# ✅ Processed 02138_00.jpg (1664/2000)
#
# ✅ Processed 02139_00.jpg (1665/2000)
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# [02140_00.jpg] Summary gen failed. Attempt 1. Retrying in 30s...
# ✅ Processed 02140_00.jpg (1666/2000)
#
# ✅ Processed 02141_00.jpg (1667/2000)
#
# ✅ Processed 02143_00.jpg (1668/2000)
#
# ✅ Processed 02144_00.jpg (1669/2000)
#
# ✅ Processed 02145_00.jpg (1670/2000)
#
# ✅ Processed 02146_00.jpg (1671/2000)
#
# ✅ Processed 02147_00.jpg (1672/2000)
#
# ✅ Processed 02148_00.jpg (1673/2000)
#
# ✅ Processed 02149_00.jpg (1674/2000)
#
# ✅ Processed 02150_00.jpg (1675/2000)
#
# ✅ Processed 02153_00.jpg (1676/2000)
#
# ✅ Processed 02154_00.jpg (1677/2000)
#
# ✅ Processed 02155_00.jpg (1678/2000)
#
# ✅ Processed 02156_00.jpg (1679/2000)
#
# ✅ Processed 02158_00.jpg (1680/2000)
#
# ✅ Processed 02159_00.jpg (1681/2000)
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# [02160_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# ✅ Processed 02160_00.jpg (1682/2000)
#
# ✅ Processed 02161_00.jpg (1683/2000)
#
# ✅ Processed 02162_00.jpg (1684/2000)
#
# ✅ Processed 02163_00.jpg (1685/2000)
#
# ✅ Processed 02164_00.jpg (1686/2000)
#
# ✅ Processed 02165_00.jpg (1687/2000)
#
# ✅ Processed 02166_00.jpg (1688/2000)
#
# ✅ Processed 02168_00.jpg (1689/2000)
#
# ✅ Processed 02170_00.jpg (1690/2000)
#
# ✅ Processed 02172_00.jpg (1691/2000)
#
# ✅ Processed 02173_00.jpg (1692/2000)
#
# ✅ Processed 02174_00.jpg (1693/2000)
#
# ✅ Processed 02175_00.jpg (1694/2000)
#
# ✅ Processed 02177_00.jpg (1695/2000)
#
# ✅ Processed 02178_00.jpg (1696/2000)
#
# ✅ Processed 02181_00.jpg (1697/2000)
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# [02182_00.jpg] Summary gen failed. Attempt 1. Retrying in 30s...
# ✅ Processed 02182_00.jpg (1698/2000)
#
# ✅ Processed 02183_00.jpg (1699/2000)
#
# ✅ Processed 02185_00.jpg (1700/2000)
#
# ✅ Processed 02186_00.jpg (1701/2000)
#
# ✅ Processed 02187_00.jpg (1702/2000)
#
# ✅ Processed 02188_00.jpg (1703/2000)
#
# ✅ Processed 02189_00.jpg (1704/2000)
#
# ✅ Processed 02190_00.jpg (1705/2000)
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# [02191_00.jpg] Summary gen failed. Attempt 1. Retrying in 30s...
# ✅ Processed 02191_00.jpg (1706/2000)
#
# ✅ Processed 02192_00.jpg (1707/2000)
#
# ✅ Processed 02193_00.jpg (1708/2000)
#
# ✅ Processed 02195_00.jpg (1709/2000)
#
# ✅ Processed 02197_00.jpg (1710/2000)
#
# ✅ Processed 02199_00.jpg (1711/2000)
#
# ✅ Processed 02200_00.jpg (1712/2000)
#
# ✅ Processed 02201_00.jpg (1713/2000)
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
# [02202_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# ✅ Processed 02202_00.jpg (1714/2000)
#
# ✅ Processed 02203_00.jpg (1715/2000)
#
# ✅ Processed 02205_00.jpg (1716/2000)
#
# ✅ Processed 02206_00.jpg (1717/2000)
#
# ✅ Processed 02209_00.jpg (1718/2000)
#
# ✅ Processed 02210_00.jpg (1719/2000)
#
# ✅ Processed 02211_00.jpg (1720/2000)
#
# ✅ Processed 02212_00.jpg (1721/2000)
#
# ✅ Processed 02213_00.jpg (1722/2000)
#
# ✅ Processed 02214_00.jpg (1723/2000)
#
# ✅ Processed 02215_00.jpg (1724/2000)
#
# ✅ Processed 02216_00.jpg (1725/2000)
#
# ✅ Processed 02217_00.jpg (1726/2000)
#
# ✅ Processed 02218_00.jpg (1727/2000)
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# [02219_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# ✅ Processed 02219_00.jpg (1728/2000)
#
# ✅ Processed 02220_00.jpg (1729/2000)
#
# ✅ Processed 02222_00.jpg (1730/2000)
#
# ✅ Processed 02223_00.jpg (1731/2000)
#
# ✅ Processed 02224_00.jpg (1732/2000)
#
# ✅ Processed 02225_00.jpg (1733/2000)
#
# ✅ Processed 02226_00.jpg (1734/2000)
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# [02227_00.jpg] Summary gen failed. Attempt 1. Retrying in 30s...
# ✅ Processed 02227_00.jpg (1735/2000)
#
# ✅ Processed 02228_00.jpg (1736/2000)
#
# ✅ Processed 02229_00.jpg (1737/2000)
#
# ✅ Processed 02230_00.jpg (1738/2000)
#
# ✅ Processed 02231_00.jpg (1739/2000)
#
# ✅ Processed 02232_00.jpg (1740/2000)
#
# ✅ Processed 02233_00.jpg (1741/2000)
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 27
# }
# ]
# [02234_00.jpg] Summary gen failed. Attempt 1. Retrying in 30s...
# ✅ Processed 02234_00.jpg (1742/2000)
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 54
# }
# ]
# [02235_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 23
# }
# ]
# [02235_00.jpg] Attempt 2: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 52
# }
# ]
# [02235_00.jpg] Attempt 3: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
# [02235_00.jpg] Attempt 4: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 51
# }
# ]
# [02235_00.jpg] Attempt 5: Gemini returned None. Retrying in 30s...
# [02235_00.jpg] Failed to extract attributes after 5 attempts. Skipping.
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 20
# }
# ]
# [02236_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 50
# }
# ]
# [02236_00.jpg] Attempt 2: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ]
# [02236_00.jpg] Attempt 3: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 48
# }
# ]
# [02236_00.jpg] Attempt 4: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
# [02236_00.jpg] Attempt 5: Gemini returned None. Retrying in 30s...
# [02236_00.jpg] Failed to extract attributes after 5 attempts. Skipping.
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 46
# }
# ]
# [02237_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 15
# }
# ]
# [02237_00.jpg] Attempt 2: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 45
# }
# ]
# [02237_00.jpg] Attempt 3: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ]
# [02237_00.jpg] Attempt 4: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 43
# }
# ]
# [02237_00.jpg] Attempt 5: Gemini returned None. Retrying in 30s...
# [02237_00.jpg] Failed to extract attributes after 5 attempts. Skipping.
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ]
# [02239_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ]
# [02239_00.jpg] Attempt 2: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 11
# }
# ]
# [02239_00.jpg] Attempt 3: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
# [02239_00.jpg] Attempt 4: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 9
# }
# ]
# [02239_00.jpg] Attempt 5: Gemini returned None. Retrying in 30s...
# [02239_00.jpg] Failed to extract attributes after 5 attempts. Skipping.
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ]
# [02240_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
# [02240_00.jpg] Attempt 2: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 38
# }
# ]
# [02240_00.jpg] Attempt 3: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 7
# }
# ]
# [02240_00.jpg] Attempt 4: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ]
# [02240_00.jpg] Attempt 5: Gemini returned None. Retrying in 30s...
# [02240_00.jpg] Failed to extract attributes after 5 attempts. Skipping.
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 6
# }
# ]
# [02241_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ]
# [02241_00.jpg] Attempt 2: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 5
# }
# ]
# [02241_00.jpg] Attempt 3: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 34
# }
# ]
# [02241_00.jpg] Attempt 4: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# [02241_00.jpg] Attempt 5: Gemini returned None. Retrying in 30s...
# [02241_00.jpg] Failed to extract attributes after 5 attempts. Skipping.
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 33
# }
# ]
# [02242_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
# [02242_00.jpg] Attempt 2: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 32
# }
# ]
# [02242_00.jpg] Attempt 3: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 2
# }
# ]
# [02242_00.jpg] Attempt 4: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# [02242_00.jpg] Attempt 5: Gemini returned None. Retrying in 30s...
# [02242_00.jpg] Failed to extract attributes after 5 attempts. Skipping.
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
# [02243_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 31
# }
# ]
# [02243_00.jpg] Attempt 2: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
# [02243_00.jpg] Attempt 3: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 30
# }
# ]
# [02243_00.jpg] Attempt 4: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 59
# }
# ]
# [02243_00.jpg] Attempt 5: Gemini returned None. Retrying in 30s...
# [02243_00.jpg] Failed to extract attributes after 5 attempts. Skipping.
#
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
# [02246_00.jpg] Attempt 1: Gemini returned None. Retrying in 30s...
# API Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 58
# }
# ]
# [02246_00.jpg] Attempt 2: Gemini returned None. Retrying in 30s...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 15
#      13 if attributes_JSON is None:
#      14     print(f"[{img_file}] Attempt {attempt+1}: Gemini returned None. Retrying in {RETRY_DELAY}s...")
# ---> 15     time.sleep(RETRY_DELAY)
#      16     continue
#      18 match = re.search(r'```json\n(.*?)\n```', attributes_JSON, re.DOTALL)
#
# KeyboardInterrupt:

# %%
print(collection.count())
# Out:
# 1741
